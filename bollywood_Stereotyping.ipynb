# %%
import numpy as np
import pandas as pd
import re
import nltk
import spacy
import string

# %%
import gdown


url = 'https://drive.google.com/file/d/1L-IKRoWUAk96cmxnwzEGazb7VyDIFKTK/view?usp=drive_link'
file_id = url.split('/')[-2]
gdown_url = f'https://drive.google.com/uc?id={file_id}'
data = pd.read_csv(gdown_url)
print(data.head())
# Out:
#     movieName                                             Script
# 0      Haider  During the insurgency in Kashmir, which contin...
# 1     Kaminey  Charlie Sharma and Sanjay Kumar Sharma (Guddu)...
# 2     Highway  Veera Tripathi (Alia Bhatt) is the daughter of...
# 3  Jab we met  Aditya Kashyap, heir to a wealthy but broken f...
# 4     Maqbool  The film is based on William Shakespeare's Mac...

# %%
data.head()
# Out:
#     movieName                                             Script
# 0      Haider  During the insurgency in Kashmir, which contin...
# 1     Kaminey  Charlie Sharma and Sanjay Kumar Sharma (Guddu)...
# 2     Highway  Veera Tripathi (Alia Bhatt) is the daughter of...
# 3  Jab we met  Aditya Kashyap, heir to a wealthy but broken f...
# 4     Maqbool  The film is based on William Shakespeare's Mac...

# %%
df = data[["Script"]]
df["Script"] = df["Script"].astype(str)

# %%
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

def nlp_preprocessing(text):
    # Same preprocessing steps as before
    text_lower = text.lower()
    tokens = word_tokenize(text_lower)
    tokens = [token for token in tokens if token not in string.punctuation]
    stop_words = set(stopwords.words("english"))
    tokens = [token for token in tokens if token not in stop_words]
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    tokens = [token for token in tokens if token.isalpha()]
    preprocessed_text = " ".join(tokens)
    return preprocessed_text


# Apply NLP preprocessing to the "Script" column directly
data["Script"] = data["Script"].apply(nlp_preprocessing)

# %%
data.head()
# Out:
#     movieName                                             Script
# 0      Haider  insurgency kashmir continues hilaal meer docto...
# 1     Kaminey  charlie sharma sanjay kumar sharma guddu twin ...
# 2     Highway  veera tripathi alia bhatt daughter manik kumar...
# 3  Jab we met  aditya kashyap heir wealthy broken family depr...
# 4     Maqbool  film based william shakespeare macbeth mumbai ...

# %%
# !pip install gender-guesser

# %%
pip install spacy

# %%
# import spacy
# import pandas as pd
# import re

# # Load the spaCy NLP model with NER capabilities
# nlp = spacy.load("en_core_web_sm")

# # Function to identify character names from the movie plot text using NER
# def identify_character_names(text):
#     doc = nlp(text)
#     character_names = [ent.text for ent in doc.ents if ent.label_ == "PERSON"]
#     return character_names

# # Assuming you have loaded your CSV data into a DataFrame named 'data'
# # Apply NER to the "Script" column to get character names
# data["Character_Names"] = data["Script"].apply(identify_character_names)

# # Function to clean and extract main character names from the list of entities
# def clean_character_names(names):
#     cleaned_names = set()
#     for name in names:
#         # Use regular expression to remove titles or descriptions from the name
#         cleaned_name = re.sub(r"(\b[A-Z][a-z]*\b\s*)+", "", name).strip()
#         cleaned_names.add(cleaned_name)
#     return cleaned_names

# # Clean character names to remove titles or descriptions
# data["Character_Names"] = data["Character_Names"].apply(clean_character_names)

# # Filter out empty sets (if any) caused by cleaning
# data = data[data["Character_Names"].map(len) > 0]

# # Display the DataFrame with character names identified from the movie plots
# print(data[["movieName", "Character_Names"]])

# %%
# print(data[["Character_Names"]])

# %%
data.head()
# Out:
#     movieName                                             Script  \
# 0      Haider  insurgency kashmir continues hilaal meer docto...
# 1     Kaminey  charlie sharma sanjay kumar sharma guddu twin ...
# 2     Highway  veera tripathi alia bhatt daughter manik kumar...
# 3  Jab we met  aditya kashyap heir wealthy broken family depr...
# 4     Maqbool  film based william shakespeare macbeth mumbai ...
#
#                                      Character_Names
# 0                  [ghazala khurram, khurram arshia]
# 1  [charlie sharma, kumar sharma, charlie, mikhai...
# 2  [veera tripathi, bhatt daughter, kumar tripath...
# 3  [aditya kashyap heir, bhatinda, dharamraj kash...
# 4  [william, miyan maqbool irrfan, khan, jahangir...

# %%
data.head()
# Out:
#     movieName                                             Script  \
# 0      Haider  insurgency kashmir continues hilaal meer docto...
# 1     Kaminey  charlie sharma sanjay kumar sharma guddu twin ...
# 2     Highway  veera tripathi alia bhatt daughter manik kumar...
# 3  Jab we met  aditya kashyap heir wealthy broken family depr...
# 4     Maqbool  film based william shakespeare macbeth mumbai ...
#
#                                      Character_Names
# 0                  [ghazala khurram, khurram arshia]
# 1  [charlie sharma, kumar sharma, charlie, mikhai...
# 2  [veera tripathi, bhatt daughter, kumar tripath...
# 3  [aditya kashyap heir, bhatinda, dharamraj kash...
# 4  [william, miyan maqbool irrfan, khan, jahangir...
